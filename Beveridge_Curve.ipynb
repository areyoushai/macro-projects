# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.ticker as mtick
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandaSDMX -U

# %%
import pip

# %%
# !pip install pandaSDMX -U

# %%
# !pip install numpy

# %%
# !pip3 install pandaSDMX -U

# %%
pip3 install --upgrade pip
# Out:
#   Cell In[137], line 1
#     pip3 install --upgrade pip
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlib.ticker as mtick
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %%
pip3 install pandas

# %%
# !pip3 install pandas

# %%
# !pip3 install numpy
# !pip3 install Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.ticker as mtick
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %%
# !pip3 install numpy

# %%
import numpy as np

# %%
# !/usr/local/Cellar/jupyterlab/3.0.13/libexec/bin/python3.9 -m pip install scipy matplotlib

# %%
import sys
sys.executable

# %%
# !/opt/homebrew/Cellar/jupyterlab/4.0.10/libexec/bin/python -m pip install scipy matplotlib

# %%
import numpy as np

# %%
import pandas as pd

# %%
# !/opt/homebrew/Cellar/jupyterlab/4.0.10/libexec/bin/python -m pip install scipy pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.0.10/libexec/bin/python -m pip install --upgrade pip

# %%
# !/opt/homebrew/Cellar/jupyterlab/4.0.10/libexec/bin/python -m pip install scipy pandaSDMX -U
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.9/217.9 kB 4.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 6.1 MB/s eta 0:00:0000:0100:01m
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.0.10/libexec/bin/python -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.ticker as mtick
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %%
# !/opt/homebrew/Cellar/jupyterlab/4.0.10/libexec/bin/python -m pip install scipy pandas_datareader
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.0.10/libexec/bin/python -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.ticker as mtick
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %%
import warnings
import pandasdmx as sdmx
from datetime import date

# %%
report_start = date.fromisoformat('1948-01-01')
report_end = date.today()

# %%
data = web.get_data_fred(['CNP16OV', 'CLF16OV', 'CE16OV'], report_start, report_end)
oecd = sdmx.Request('OECD')
data_msg = oecd.data('LAB_REG_VAC', key='USA.LMJVTTUV_STSA.M/all', params={'startPeriod': report_start, 
                                                                           'endPeriod': report_end})
unfilled_vacancies = sdmx.to_pandas(data_msg.data[0]).loc['USA', 'LMJVTTUV_STSA', 'M'] / 1000
unfilled_vacancies = unfilled_vacancies.set_axis(pd.DatetimeIndex(unfilled_vacancies.index, 'MS'))
data['LMJVTTUVUSM647S'] = unfilled_vacancies

data[PARTICIPATION_RATE] = data.CLF16OV / data.CNP16OV
data[EMPLOYMENT_POPULATION_RATE] = data.CE16OV / data.CNP16OV
data[UNEMPLOYMENT_RATE] = (data.CLF16OV - data.CE16OV) / data.CLF16OV
data[UNFILLED_VACANCIES_POPULATION_RATE] = data.LMJVTTUVUSM647S / data.CNP16OV
data[UNFILLED_VACANCIES_LABOR_FORCE_RATE] = data.LMJVTTUVUSM647S / data.CLF16OV

data.rename(columns={'CNP16OV': 'Population', 'LMJVTTUVUSM647S': 'Unfilled Vacancies'}, inplace=True)

# %%
MEAN_LEVEL_OF = 'Mean level of '
PARTICIPATION_RATE = 'Participation Rate'
EMPLOYMENT_POPULATION_RATE = 'Employment Rate'
UNEMPLOYMENT_RATE = 'Unemployment Rate'
UNFILLED_VACANCIES_POPULATION_RATE = 'Unfilled Vacancies/Population Rate'
UNFILLED_VACANCIES_LABOR_FORCE_RATE = 'Job-vacancy Rate'

# %%
data = web.get_data_fred(['CNP16OV', 'CLF16OV', 'CE16OV'], report_start, report_end)
oecd = sdmx.Request('OECD')
data_msg = oecd.data('LAB_REG_VAC', key='USA.LMJVTTUV_STSA.M/all', params={'startPeriod': report_start, 
                                                                           'endPeriod': report_end})
unfilled_vacancies = sdmx.to_pandas(data_msg.data[0]).loc['USA', 'LMJVTTUV_STSA', 'M'] / 1000
unfilled_vacancies = unfilled_vacancies.set_axis(pd.DatetimeIndex(unfilled_vacancies.index, 'MS'))
data['LMJVTTUVUSM647S'] = unfilled_vacancies

data[PARTICIPATION_RATE] = data.CLF16OV / data.CNP16OV
data[EMPLOYMENT_POPULATION_RATE] = data.CE16OV / data.CNP16OV
data[UNEMPLOYMENT_RATE] = (data.CLF16OV - data.CE16OV) / data.CLF16OV
data[UNFILLED_VACANCIES_POPULATION_RATE] = data.LMJVTTUVUSM647S / data.CNP16OV
data[UNFILLED_VACANCIES_LABOR_FORCE_RATE] = data.LMJVTTUVUSM647S / data.CLF16OV

data.rename(columns={'CNP16OV': 'Population', 'LMJVTTUVUSM647S': 'Unfilled Vacancies'}, inplace=True)

# %%
data.loc['2001':]
# Out:
#             Population  CLF16OV  CE16OV  Unfilled Vacancies  \
# DATE
# 2001-01-01      213888   143800  137778              5362.0
# 2001-02-01      214110   143701  137612              5008.0
# 2001-03-01      214305   143924  137783              4698.0
# 2001-04-01      214525   143569  137299              4752.0
# 2001-05-01      214732   143318  137092              4503.0
# ...                ...      ...     ...                 ...
# 2023-08-01      267213   167840  161500              9497.0
# 2023-09-01      267428   167897  161550              9350.0
# 2023-10-01      267642   167723  161280              8852.0
# 2023-11-01      267822   168127  161866              8790.0
# 2023-12-01      267991   167451  161183                 NaN
#
#             Participation Rate  Employment Rate  Unemployment Rate  \
# DATE
# 2001-01-01            0.672314         0.644160           0.041878
# 2001-02-01            0.671155         0.642716           0.042373
# ...

# %%
data1 = data.loc['2001':]
plot = data1.plot(figsize=(10, 6))

# %%
plot = data1.iloc[:,4:6].plot(figsize=(10, 6))

# %%
plot = data1.iloc[:,4:6].plot(figsize=(10, 6), title='US Participation and Employment Rates from 2001')

# %%
plot = data1.iloc[:,4:6].plot(figsize=(10, 6), grid = TRUE, title='US Participation and Employment Rates from 2001')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 plot = data1.iloc[:,4:6].plot(figsize=(10, 6), grid = TRUE, title='US Participation and Employment Rates from 2001')
#
# NameError: name 'TRUE' is not defined

# %%
plot = data1.iloc[:,4:6].plot(figsize=(10, 6), grid=True, title='US Participation and Employment Rates from 2001')

# %%
plot = data1.iloc[:,4:6].plot(figsize=(10, 6), grid=True, title='US Participation and Employment Rates from 2001', xticks=data1.index[::12], xlabel='', rot = 40)

# %%
plot = plot.set_xticklabels(list(map('{:%Y-%m}'.format, data1.index[::12])))

# %%
plot

# %%
plot = data1.iloc[:,4:6].plot(figsize=(10, 6), grid=True, title='US Participation and Employment Rates from 2001', xticks=data1.index[::12], xlabel='', rot = 40)

# %%
plot = data1.iloc[:,4:6].plot(figsize=(10, 6), grid=True, title='US Participation and Employment Rates from 2001', xticks=data1.index[::12], xlabel='', rot = 40) 
plot = plot.set_xticklabels(list(map('{:%Y-%m}'.format, data1.index[::12])))

# %%
plot = data1.iloc[:,4:6].plot(figsize=(20, 12), grid=True, title='US Participation and Employment Rates from 2001', xticks=data1.index[::12], xlabel='', rot = 40) 
plot = plot.set_xticklabels(list(map('{:%Y-%m}'.format, data1.index[::12])))

# %%
data1.loc['2020':].iloc[:,[0,4,5,6]]

# %%
# Job Vacancies and Match Rate

plot2 = data1.iloc[:,8:].plot(figsize=(20,10), grid=True,
                                title='US Job Vacancies since 2001',
                                xticks=data1.index[::12], xlabel='', rot=40)
plot2 = plot2.set_xticklabels(list(map('{:%Y-%m}'.format, data1.index[::12])))

# %%
data1.loc['2020':].iloc[:,[3,6,7,8]].dropna()

# %%
BCurve = data1.iloc[:,[6,8]].dropna()

# %%
fig, plot3 = plt.subplots(figsize=(20, 10))
plot4 = plot3.scatter(x=BCurve.iloc[:,0], y=BCurve.iloc[:,1], c=mdates.date2num(BCurve.index))
plot3.xaxis.set_major_formatter(mtick.PercentFormatter(1))
plot3.yaxis.set_major_formatter(mtick.PercentFormatter(1))
plot3.set_xlabel('Unemployment Rate')
plot3.set_ylabel('Job Vacancy Rate')
plot3.set_title('US Beveridge Curve')
for i in (-1, -20, -26, -44, -1):
    plt.text(BCurve.iloc[i,0], BCurve.iloc[i,1], f'{BCurve.index[i]:%Y-%m}')
loc = mdates.AutoDateLocator()
_ = fig.colorbar(plot4, format=mdates.AutoDateFormatter(loc))
